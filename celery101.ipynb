# %%
from task import add
add.delay(1, 2)
# Out:
# <AsyncResult: 7b7e8e70-feb1-4857-b508-1b27916aedee>

# %%
result = add.delay(5, 6)
result.ready()
# Out:
# True

# %%
result.get(timeout=1)
# Out:
# 11

# %%
result.get(propagate=False)
# Out:
# 11

# %%
result.traceback

# %%
result
# Out:
# <AsyncResult: 4c43d97d-8a14-442d-9f7b-0fd884b43371>
