# %%
_id
:
61f3e1064f274a1d3949245b
ocrlot
:
42
index_of_lotfile
:
0
scandate
:
2022-02-02T11: 02: 13.527+00: 00
filedesinat
:
"http://192.168.1.241:3000/RecoveryScan/stlscan/ok4/2022/01/28/addrocrg..."
idcard
:
"3-2508-00061-76-7"
accu_idcard
:
100
Name
:
"น.ส.อุไร โพธิอุปถัมภ์"
gender
:
"หญิง"
nationality
:
"ไทย"
accu_name
:
100
dob
:
"15 กุมภาพันธ์ 2511"
status
:
"ผู้อาศัย"
mother
:
"อำพร"
id_mother
:
"3-2508-00061-72-4"
mothernation
:
"ไทย"
father
:
"สังเวียน"
id_father
:
"3-2508-00061-73-2"
fathernation
:
"ไทย"
address
:
"31 หมู่ 1"
TUMBUL
:
"สัมพันธ์"
AUMPUR
:
"ศรีมหาโพธิ"
PROVINCE
:
"ปราจีนบุรี"
ZIPCODE
:
25140
accu_address
:
100
stlupdate
:
null
notes
:
null
historyaddr
:
loaddate
:
null
